# %% [markdown]
# # Importing and pickling data

# %%
import random
random.seed(7)
from sas7bdat import SAS7BDAT
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from xgboost import plot_importance
from matplotlib import pyplot
import operator
from sklearn import linear_model
from scipy.stats.stats import pearsonr  
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
import scipy.spatial.distance as ssd
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from sklearn import preprocessing
from itertools import compress
import xgboost
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_recall_curve, average_precision_score
import operator
import csv
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
import iml
import xgboost
import numpy as np
import pandas as pd
import pickle
import scipy
from collections import Counter
iml.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var o=n[r]={exports:{},id:r,loaded:!1};return t[r].call(o.exports,o,o.exports,e),o.loaded=!0,o.exports}var n={};return e.m=t,e.c=n,e.p="",e(0)}([function(t,e,n){"use strict";function r(t){return t&&t.__esModule?t:{default:t}}var o=n(1),i=r(o),a=n(34),u=r(a),s=n(172),c=r(s),l=n(178),f=r(l),p=n(190),d=r(p),h=n(195),v=r(h);(0,c.default)(),window.IML={SimpleListVisualizer:f.default,AdditiveForceVisualizer:d.default,AdditiveForceArrayVisualizer:v.default,React:i.default,ReactDom:u.default}},function(t,e,n){"use strict";t.exports=n(2)},function(t,e,n){(function(e){"use strict";var r=n(4),o=n(5),i=n(17),a=n(20),u=n(21),s=n(26),c=n(9),l=n(31),f=n(32),p=n(33),d=n(11),h=c.createElement,v=c.createFactory,m=c.cloneElement;if("production"!==e.env.NODE_ENV){var g=n(27);h=g.createElement,v=g.createFactory,m=g.cloneElement}var y=r;if("production"!==e.env.NODE_ENV){var _=!1;
# ...

# %%
with SAS7BDAT('/homes/gws/ruqian/projects/kidney/data/Derived_Data/visitlevel.sas7bdat') as f:
    df = f.to_data_frame()

# %%
df
# Out:
#             PID  VNUM     TG     TC   HDL    LDL  VLDL  ALANINE_AMINOTRANSFE  \
# 0      01010001   3.0  101.0  168.0  65.0   77.0  26.0                  26.0
# 1      01010001   4.0    NaN    NaN   NaN    NaN   NaN                   NaN
# 2      01010001   5.0  110.0  198.0  67.0  113.0  18.0                  37.0
# 3      01010001   6.0    NaN    NaN   NaN    NaN   NaN                   NaN
# 4      01010001   7.0   50.0  152.0  69.0   76.0   7.0                  28.0
# 5      01010001   8.0    NaN    NaN   NaN    NaN   NaN                   NaN
# 6      01010001   9.0   83.0  148.0  62.0   68.0  18.0                  36.0
# 7      01010001  10.0    NaN    NaN   NaN    NaN   NaN                   NaN
# 8      01010001  11.0   79.0  156.0  62.0   80.0  14.0                  30.0
# 9      01010001  12.0    NaN    NaN   NaN    NaN   NaN                   NaN
# 10     01010001  13.0   73.0  179.0  74.0   91.0  14.0                  25.0
# ...

# %% [markdown]
# ## Pickling

# %%
with open('info.pickle', 'wb') as handle:
    pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Examining data

# %%
df.shape # 49043 observations, 385 features
# Out:
# (49043, 385)

# %%
len(np.asarray(df[['PID']].drop_duplicates())) # = 3939, number of patients
# Out:
# 3939

# %%
list(df.columns) # the features in this data frame
# Out:
# ['PID',
#  'VNUM',
#  'TG',
#  'TC',
#  'HDL',
#  'LDL',
#  'VLDL',
#  'ALANINE_AMINOTRANSFE',
#  'SERUM_ALBUMIN',
#  'ALKALINE_PHOSPHATASE',
#  'ASPARTATE_AMINOTRANS',
#  'CALCIUM',
#  'CHLORIDE',
#  'GLUCOSE',
#  'HEMOGLOBIN_A1C',
#  'MAGNESIUM',
#  'PHOSPHATE',
#  'POTASSIUM',
#  'SODIUM',
#  'TOTAL_BILIRUBIN',
#  'TOTAL_PLASMA_HOMOCYS',
#  'TOTAL_PROTEIN',
#  'SERUM_UREA_NITROGEN',
#  'URIC_ACID',
#  'URINE_TOTAL_VOLUME',
#  'MCH',
#  'MCHC',
#  'MCV',
#  'RBC',
#  'URINE_PROTEIN_MG_DL',
#  'UTP_SELECTED_R',
#  'CREATININE_SERUM',
#  'WBC',
#  'ACE_INH',
#  'ALPHA2AG',
#  'ALPHABLK',
#  'ANGIOBLK',
#  'ANTIDIABETES',
#  'ANTIPLATELET',
#  'ANXIOLYTICS',
#  'BETABLK',
#  'CABLK',
#  'CORONARY',
#  'DIURETIC',
#  'INSULIN',
#  'KSPARE_DIURETIC',
#  'LIPID',
#  'LOOP_DIURETIC',
#  'NON_SEL_SRI',
#  'SSRI',
#  'THIAZ_DIURETIC',
#  'VASODIL',
#  'ACTIVE_VITD',
#  'SULFONYLUREA',
#  'BIGUANIDE',
#  'ALPHA_GLUCO_INH',
#  'TZD',
#  'MEGLITINIDE',
#  'DPP4',
#  'STATINS',
# ...

# %% [markdown]
# ## Histogram of max length of visitation per patient
#
# TODO

# %%
df[['DAYS_THISVISIT']]==0
# Out:
#       DAYS_THISVISIT
# 0               True
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20              True
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
# 28             False
# 29             False
# ...              ...
# 49013          False
# 49014          False
# 49015          False
# 49016          False
# 49017          False
# 49018          False
# 49019          False
# 49020          False
# 49021          False
# 49022          False
# 49023          False
# ...

# %% [markdown]
# ## Histogram of how many visits per patient
# TODO

# %% [markdown]
# # Three clinically interesting outcome
# - doubling of creatinine serum from baseline
# - 30% eGFR decline from baseline
# - declaration of ESRD
#
# After consulting with the doctors, we decided on two outcomes and possibly combining them: 30% eGFR decline from baseline and declaration of ESRD

# %% [markdown]
# ## First, we remove patients who are already near end-stage renal desease, i.e. those with baseline eGFR < 20.

# %% [markdown]
# ### How many such patients are there?
# How many more visits do they have before declaring ESRD? This is not crucial to the study, but shows how good this assumption that those with eGFR < 20 is near end-stage is.

# %% [markdown]
# ## Second, we separate the features into groups, and remove the deleted features.

# %%
# This is a hand-coded dictionary of feature groups.
with open('varDictInd0.pickle', 'rb') as handle:
    varDictInd = pickle.load(handle)

# %%
varDictInd
# Out:
# {'ABICAT': 0,
#  'ACEARB': '2',
#  'ACE_INH': '2',
#  'ACIDOSIS': 15,
#  'ACTIVE_VITD': '5',
#  'ADJUSTED_IGFR': 6,
#  'AFIB': 15,
#  'AGE': 15,
#  'AGE_CAT_1': 0,
#  'AGE_CAT_2': 0,
#  'AGE_INTEGER': 0,
#  'ALANINE_AMINOTRANSFE': 15,
#  'ALBUMINURIA': '1',
#  'ALCOHOL_DHQ': 8,
#  'ALCOH_USE': 15,
#  'ALDOSTERONE': 15,
#  'ALDO_ANTAGONIST': '2',
#  'ALKALINE_PHOSPHATASE': 15,
#  'ALLOPURINOL': 15,
#  'ALPHA2AG': '2',
#  'ALPHABLK': '2',
#  'ALPHA_GLUCO_INH': 15,
#  'AMPFLAG_BMI': 15,
#  'AMPFLAG_HEIGHT': 15,
#  'AMPUTATION': 15,
#  'ANEMIA': 14,
#  'ANGIOBLK': '2',
#  'ANTIDEPRESSANT': 13,
#  'ANTIDIABETES': '4',
#  'ANTIEPILEPTICS': 15,
#  'ANTIPLATELET': 15,
#  'ANTI_ACIDOSIS': 15,
#  'ANXIOLYTICS': 13,
#  'ANYCVD': 15,
#  'ANYILLICIT': 15,
#  'ANYLSMOD': 15,
#  'ANY_HVY': 12,
#  'AOV_CW_PEAK_VELOCITY': 9,
#  'ARG': 15,
#  'ARTHRITIS': 15,
#  'ASPARTATE_AMINOTRANS': 15,
#  'ASPIRIN': 15,
#  'ASTHMA': 15,
#  'BASOPHILS': 14,
#  'BECKS_SCORE': 13,
#  'BETABLK': '2',
# ...

# %% [markdown]
# ## Third, we prepare end-stage dictionaries:
# key: PID
# value: 0 or 1.

# %%
crs_baseline_dict  = {}
egfr_less_20_dict = {}
esrd_eventually_dict = {}
first_row_dict = {}
pid_tmp = df [['PID']].values.reshape(1,df.shape[0])[0]
crs_tmp = df [['CREATININE_SERUM']].values.reshape(1,df.shape[0])[0]
esrd_tmp = df [['ESRD']].values.reshape(1,df.shape[0])[0]
egfr_tmp = df [['EGFR_CKD_EPI']].values.reshape(1,df.shape[0])[0]

# %% [markdown]
# ### first_row_dict
#
# key: PID, a patient
# value: row number of key patient's baseline visit

# %%
for i in np.arange( df.shape[0]):
    key = pid_tmp[i]
    crs_baseline_dict.setdefault(key, crs_tmp[i])
    first_row_dict.setdefault(key, i)

# %%
first_row_dict
# Out:
# {'01010001': 0,
#  '01010006': 20,
#  '01010007': 40,
#  '01010008': 51,
#  '01010011': 61,
#  '01010013': 79,
#  '01010015': 96,
#  '01010016': 116,
#  '01010017': 120,
#  '01010021': 137,
#  '01010022': 156,
#  '01010026': 173,
#  '01010028': 191,
#  '01010029': 210,
#  '01010031': 229,
#  '01010033': 243,
#  '01010034': 261,
#  '01010035': 279,
#  '01010036': 287,
#  '01010037': 301,
#  '01010038': 311,
#  '01010043': 327,
#  '01010044': 343,
#  '01010047': 360,
#  '01010051': 373,
#  '01010053': 381,
#  '01010055': 386,
#  '01010057': 402,
#  '01010058': 420,
#  '01010059': 438,
#  '01010060': 446,
#  '01010062': 463,
#  '01010063': 479,
#  '01010064': 488,
#  '01010065': 497,
#  '01010068': 504,
#  '01010070': 515,
#  '01010071': 532,
#  '01010076': 549,
#  '01010080': 566,
#  '01010083': 583,
#  '01010084': 602,
#  '01010086': 608,
#  '01010087': 627,
#  '01010093': 646,
#  '01010094': 663,
#  '01010098': 676,
#  '01010100': 695,
#  '01010104': 714,
#  '01010111': 731,
# ...

# %% [markdown]
# ### egfr_less_20_dict

# %%
for key in first_row_dict:
    row_curr = first_row_dict[key]
    value_curr = egfr_tmp[row_curr]
    if np.isnan(value_curr): print(key) # will turn out that all patients have egfr measured on first visit
    if value_curr < 20: egfr_less_20_dict.setdefault(key, 1)
    else: egfr_less_20_dict.setdefault(key, 0)
print(sum(list(egfr_less_20_dict.values())), 'many patients have baseline EGFR_CKD_EPI < 20')
# Out:
# 93 many patients have baseline EGFR_CKD_EPI < 20

# %% [markdown]
# ### esrd_eventually_dict

# %%
for i in np.arange(df.shape[0]):
    esrd_eventually_dict.setdefault(pid_tmp[i],0)
for i in np.arange(df.shape[0]):
    esrd_curr = esrd_tmp[i]
    if esrd_curr == 1:
        esrd_eventually_dict[pid_tmp[i]]=1

# %%
np.sum(np.array(list(esrd_eventually_dict.values())))
# Out:
# 829

# %% [markdown]
# ### crs_doubling_dict

# %%
crs_doubling_dict= {}
for i in np.arange(df.shape[0]):
    pid_curr = pid_tmp[i]
    crs_doubling_dict.setdefault(pid_curr,0)
for i in np.arange(df.shape[0]):
    pid_curr = pid_tmp[i]
    crs_curr = crs_tmp[i]
    crs_base = crs_baseline_dict[pid_curr]
    if crs_curr > 2* crs_base:
        crs_doubling_dict[pid_curr] = 1

# %%
np.sum(np.array(list(crs_doubling_dict.values())))
# Out:
# 713

# %% [markdown]
# ### egfr_decline_dict

# %%
# Similarly build this dictionary.
# key: PID
# value: 1 if a patient has a visit-level eGFR level < 70% of their baseline value
#        0 otherwise

# %%
# for easiness I load them
# the following dictionary already take into account the egfr_less_20_dict,
# that is, all patients whose baseline eGFR are < 20 are removed
with open('crs_doubling_dict.pickle', 'rb') as handle:
    crs_doubling_dict  = pickle.load(handle)
with open('esrd_eventually_dict.pickle', 'rb') as handle:
    esrd_eventually_dict = pickle.load(handle)
with open('egfr_decline_dict.pickle', 'rb') as handle:
    egfr_decline_dict = pickle.load(handle)

# %% [markdown]
# # Preparing training / test data and labels

# %%
curr_dict = egfr_decline_dict
model_name = "egfr_decline"
y_data = []
x_row = []
for key in egfr_less_20_dict:
    if egfr_less_20_dict[key] == 0:
        y_data.append(curr_dict[key])
        x_row.append(first_row_dict[key])

# %%
test_size = 0.33
x_first_visit = df.iloc[x_row]
x_first_visit_selected=x_first_visit.drop('PID',axis = 1)
valid_column = []
for t in varDictInd:
    if int(varDictInd[t]) != 0:
        valid_column.append(t)
X_train, X_test, y_train, y_test = train_test_split(x_first_visit_selected[valid_column], y_data, test_size=test_size, random_state=7)
xgb_data = xgboost.DMatrix(X_train, label=y_train)
xgb_data_test = xgboost.DMatrix(X_test, label=y_test)

# %%
params = {
    "eta": 0.001,
    "subsample": 0.5,
    "max_depth": 1,
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "base_score": np.mean(y_train)
}
model1 = xgboost.cv(params, xgb_data, num_boost_round=10000)
plt.plot(model1[['test-logloss-mean']].values.flatten()[0:])
plt.show()

# %%
plt.plot(model1[['test-logloss-mean']].values.flatten()[8000:])
plt.title("starting at 8000 trees")
plt.show()

# %%
print(np.min(model1[['test-logloss-mean']].values.flatten()))
print(np.argmin(model1[['test-logloss-mean']].values.flatten()))
argmin_tree = np.argmin(model1[['test-logloss-mean']].values.flatten())
# Out:
# 0.492646333333
# 9794

# %%
eval_dict_depth1={}
xgb_data = xgboost.DMatrix(X_train, label=y_train)
params = {
    "eta": 0.001,
    "subsample": 0.5,
    "max_depth": 1,
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "base_score": np.mean(y_train)
}
#argmin_tree = 9794
model1train = xgboost.train(params, xgb_data, num_boost_round=argmin_tree,evals = [(xgb_data_test, "test")],
                      verbose_eval = False, evals_result = eval_dict_depth1)

# %%
predictionFF = model1train.predict(xgb_data_test, pred_contribs=False,output_margin=False)
precision, recall, thresholds = precision_recall_curve(y_test,  predictionFF)
print('There are ',len(X_test),'many patients in test data.')
# ref: http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#sphx-glr-auto-examples-model-selection-plot-precision-recall-py
plt.clf()
plt.plot(recall, precision, lw=1, color='purple',
         label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.title('ESRD, '+'Precision-Recall, '+ str(len(y_test)) +' patients: AUC={0:0.2f}'.format(average_precision_score(y_test, predictionFF)))
plt.legend(loc="lower left")
plt.grid()
plt.show()
# Out:
# There are  1270 many patients in test data.

# %% [markdown]
# ### Having optimized a model with depth 1 trees, can we improve log loss by further adding depth 2 trees?

# %%
# fill in

# %% [markdown]
# ### How about a different model entirely? Let's compare the ROC curves of XGBoost and Logistic Regerssion.

# %%
# To train logistic regression, we must remove the nans in the training/test data.
# We can just fill nans with column means. For those columns with all nan, we simply remove.
# Below are columns with mean = nan, aka all nan.
for i, t in enumerate(np.isnan(X_train.mean())):
    if t == True:
        print("'"+list(X_train.columns)[i]+"',")
# Out:
# 'UTP_SELECTED_R',
# 'URINE_CREATININE_R',
# 'PHYSICAL_LIMITATION',
# 'SYMPTOM_STABILITY',
# 'SYMPTOM_FREQUENCY',
# 'SYMPTOM_BURDEN',
# 'TOTAL_SYMPTOM',
# 'SELF_EFFICACY',
# 'QUALITY_OF_LIFE',
# 'SOCIAL_LIMITATION',
# 'OVERALL_SUMMARY',
# 'CLINICAL_SUMMARY',
# 'AMPFLAG_HEIGHT',
# 'AMPFLAG_BMI',
# 'PCR_SPOT',

# %%
from sklearn.linear_model import LogisticRegression
X_train_tmp = X_train.fillna(X_train.mean())
X_train_tmp = X_train_tmp.drop(['UTP_SELECTED_R',
'URINE_CREATININE_R',
'PHYSICAL_LIMITATION',
'SYMPTOM_STABILITY',
'SYMPTOM_FREQUENCY',
'SYMPTOM_BURDEN',
'TOTAL_SYMPTOM',
'SELF_EFFICACY',
'QUALITY_OF_LIFE',
'SOCIAL_LIMITATION',
'OVERALL_SUMMARY',
'CLINICAL_SUMMARY',
'AMPFLAG_HEIGHT',
'AMPFLAG_BMI',
'PCR_SPOT'],axis = 1)
logit1=LogisticRegression()
logit1=LogisticRegression()
logit1.fit(X_train_tmp,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
X_test_tmp = X_test.fillna(X_test.mean())
X_test_tmp = X_test_tmp.drop(['UTP_SELECTED_R',
'URINE_CREATININE_R',
'PHYSICAL_LIMITATION',
'SYMPTOM_STABILITY',
'SYMPTOM_FREQUENCY',
'SYMPTOM_BURDEN',
'TOTAL_SYMPTOM',
'SELF_EFFICACY',
'QUALITY_OF_LIFE',
'SOCIAL_LIMITATION',
'OVERALL_SUMMARY',
'CLINICAL_SUMMARY',
'AMPFLAG_HEIGHT',
'AMPFLAG_BMI',
'PCR_SPOT'], axis = 1)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
fpr, tpr, thresholds  = roc_curve(y_test, predictionFF,pos_label=1)
preds = logit1.predict_proba(X_test_tmp)[:,1]
fpr_reg, tpr_reg, thresholds_reg = roc_curve(y_test, preds, pos_label = 1)
plt.plot(fpr_reg, tpr_reg,'r',label = "Logistic Regression, AUC = 0.73")
plt.plot(fpr, tpr,'b', label = 'XGBoost 9794 Depth-1 trees, AUC = 0.79')
plt.legend()
#plt.title("ROC curve of 30% eGFR decline\n AUC = "+str(round(roc_auc_score(y_test, preds),2)))
plt.title("ROC Curve of the Composite Outcome")
plt.show()

# %% [markdown]
# From above, we see that XGBoost performs better than logistic regression. We'd like to choose a more complicated but better model in terms of performance metrics, but we would also like to understand the model. Here comes the explainer.

# %% [markdown]
# # Explain

# %%
def explain_bst(out, data, feature_names):
    if out.shape[0] == 1:
        instance = iml.Instance(data[0:1,:], data[0,:])
        e = iml.AdditiveExplanation(out[0,-1], np.sum(out[0,:]), out[0,:-1], None, instance, iml.IdentityLink(), iml.Model(None, ["out value"]), iml.DenseData(np.zeros((1,data.shape[1])), feature_names))
        return e
    else:
        exps = []
        for i in range(out.shape[0]):
            instance = iml.Instance(data[i:i+1,:], data[i,:])
            e = iml.AdditiveExplanation(out[i,-1], np.sum(out[i,:]), out[i,:-1], None, instance, iml.IdentityLink(), iml.Model(None, ["out value"]), iml.DenseData(np.zeros((1,data.shape[1])), feature_names))
            exps.append(e)
        return exps

# %%
predictionTT = model1train.predict(xgb_data_test, pred_contribs = True,output_margin = True)
prediction_matrix = np.matrix(predictionTT)
print(prediction_matrix.shape)
prediction_matrix
# Out:
# (1270, 342)
# matrix([[  6.40662536e-02,   1.26598708e-04,   2.05642704e-04, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01],
#         [ -6.61975145e-03,   1.26598708e-04,   2.05642704e-04, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01],
#         [ -6.61975145e-03,   1.26598708e-04,   3.58111947e-03, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01],
#         ...,
#         [ -6.61975145e-03,   1.26598708e-04,   2.05642704e-04, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01],
#         [ -6.61975145e-03,   1.26598708e-04,   2.05642704e-04, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01],
#         [  2.63825115e-02,   1.26598708e-04,   2.46191164e-04, ...,
#            0.00000000e+00,   0.00000000e+00,  -8.27944040e-01]], dtype=float32)

# %%
group_names=['UACR/PCR',
 'BP',
 'CHOLESTEROL',
 'GLUCOSE/DM',
 'MINERAL/METAB',
 'EGFR/IGFR',
 'QOL/SX',
 'DIET',
 'ECHO',
 'BMI/WEIGHT',
 'B/A',
 'PHYSICAL ACTIVITY',
 'DEPRESSION',
 'HEMATOLOGY',
 'Misc.']

# %%
predLength = prediction_matrix.shape[0]
num_column = A.shape[1]
A= np.zeros((predLength, 16))
A = np.matrix(A)
for i,t in enumerate(list(X_train.columns)):
    feature_group = int(varDictInd[t])
    A[:,feature_group-1] += prediction_matrix[:,i]
A[:,15] = prediction_matrix[:,num_column]
print(A.shape)
B= np.random.rand(predLength, 15)
# Out:
# (1270, 16)

# %%
#explanations = explain_bst(np.array(prediction_matrix), np.array(X_test), list(X_test.columns))
explanations = explain_bst(np.array(A), np.array(B), group_names)

arr = explanations
m = np.vstack([e.effects for e in arr])
print(m.shape)
D = np.vstack([np.sum((m - m[i,:])**2, 1) for i in range(m.shape[0])])
print(D.shape)
clusterOrder = scipy.cluster.hierarchy.leaves_list(scipy.cluster.hierarchy.complete(D))
print(len(clusterOrder))
#iml.visualize([explanations[i] for i in clusterOrder[0:219]])
order = np.argsort(abs(predictionTT).sum(axis=0))[::-1]
order
# Out:
# (1270, 15)
# (1270, 1270)
# /homes/gws/ruqian/anaconda3/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:287: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='complete', metric='euclidean')
# 1270
# array([341, 224, 219,  81, 221, 218,  10,   6, 332,  13,  27, 164, 209,
#         39, 145, 147, 226, 155, 235, 210, 165, 236, 167, 144, 154, 146,
#        124, 166,   5, 228, 232,  67, 335, 200,   0,   9, 208, 153, 267,
#        194, 231, 255, 156, 168, 227,   7, 199,  26, 238, 142, 252, 151,
#         19, 223, 132, 205, 229,  23, 230, 265,  20,  18, 253,  12,  16,
#         15, 195, 125, 333, 152,  91, 148, 213, 289, 237,  84, 103, 192,
#          4, 102,  52, 134, 266,  21, 157, 275, 193,  89,  30, 326,  35,
#        215, 136,  25, 211, 214, 137, 104,  82, 120, 149, 271, 245,  85,
#        204, 161, 242, 114,   3, 172, 115, 260, 150, 116,  14, 112, 247,
# ...

# %% [markdown]
# # Check how SHAP values change with each feature

# %%
def shapvsfeature(t):
    curr_size = Counter([int(x) for x in list(varDictInd.values())])[i]
    #plt.title(model_name+": SHAP value vs feature value" + "#"+str(t))
    plt.title("30% decline eGFR")
    plt.scatter((X_test.ix[:,t].values.flatten()),predictionTT[:,t],marker='.',alpha =0.7,s=2,c='purple')
    plt.xlabel(list(X_train.columns)[t], fontsize=16)
    plt.ylabel('SHAP (change in log odds)', fontsize=16)
    ax = plt.gca()
    ax.set_ylim(-0.7,0.7)
    #ax.set_xscale("log", nonposx='clip')
    plt.show()
def shapvsfeaturelog(t):
    curr_size = Counter([int(x) for x in list(varDictInd.values())])[i]
    #plt.title(model_name+": SHAP value vs feature value (log-scale) " + "#"+str(t))
    plt.title("30% decline eGFR ")
    plt.scatter((X_test.ix[:,t].values.flatten()),predictionTT[:,t],marker='.',alpha =0.7,s=0.1,c='purple')
    plt.xlabel(list(X_train.columns)[t] + ' (log scale axis)', fontsize=16)
    plt.ylabel('SHAP (change in log odds)', fontsize=16)
    ax = plt.gca()
    ax.set_ylim(-0.7,0.7)
    ax.set_xscale("log", nonposx='clip')
    plt.show()

# %%
for t in order[1:10]:
    shapvsfeature(t)
    shapvsfeaturelog(t)

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster.bicluster import SpectralBiclustering

# %%
data_original = prediction_matrix[:400,:341]
data_original.shape
data = data_original[:]
n_clusters = (16,16)
model = SpectralBiclustering(n_clusters=n_clusters, method='log',
                             random_state=0)
model.fit(data)
fit_data = data[np.argsort(model.row_labels_)]
fit_data = fit_data[:, np.argsort(model.column_labels_)]

#plt.matshow(fit_data, cmap=plt.cm.Blues)
#plt.title("After biclustering; rearranged to show biclusters")

plt.matshow(np.outer(np.sort(model.row_labels_) + 1,
                     np.sort(model.column_labels_) + 1),
            cmap=plt.cm.Blues)
plt.title("Checkerboard structure of rearranged data \nwith 8 patient groupd and 8 feature groups\n")

plt.show()

# %%
data_original = prediction_matrix[:,:341]
data_original.shape
data = data_original[:]
n_clusters = (10,16)
model = SpectralBiclustering(n_clusters=n_clusters, method='log',
                             random_state=0)
model.fit(data)
fit_data = data[np.argsort(model.row_labels_)]
fit_data = fit_data[:, np.argsort(model.column_labels_)]

#plt.matshow(fit_data, cmap=plt.cm.Blues)
#plt.title("After biclustering; rearranged to show biclusters")

plt.matshow(np.outer(np.sort(model.row_labels_) + 1,
                     np.sort(model.column_labels_) + 1),
            cmap=plt.cm.Blues)
plt.title("Checkerboard structure of rearranged data\nwith 10 patient groupd and 16 feature groups\n")

plt.show()

# %% [markdown]
# # Genetic data

# %%
import pandas_plink as ppl; ppl.test()
from pandas_plink import read_plink
from pandas_plink import example_file_prefix
# Out:
# ..
# 2 passed in 4.59 seconds
# Congratulations. All tests have passed!

# %%
path = './phg000317.v1.NIDDK_ChronicRenalInsufficiency.genotype-calls-matrixfmt.c1.AHC/phs000524_cg1'
(bim, fam, bed) = ppl.read_plink(path)
# Out:
# Mapping files: 100%|██████████| 3/3 [00:02<00:00,  1.48s/it]

# %%
from scipy.stats import t
def b1 (x, y): # slope of the regression line, same as `model.coef_`
    return sum((x - np.mean(x)) * (y - np.mean(y))) /sum(( (x - np.mean(x))*(x - np.mean(x))))
def b0 (x, y): # intercept of the regression line, same as `model.intercept_`
    return np.mean(y) - b1(x,y) * np.mean(x)
def y_pred(model, x): # linear regression model
    return model.coef_ * x + model.intercept_
def y_pred_scratch(b1_val,b0_val,x):
    return b1_val*x + b0_val
def se (y_hat, y_true): # standard error 
    ans = np.sqrt(sum( (y_hat-y_true)*(y_hat-y_true)  ) / len(y_hat))
    return ans
def t_df(y): # degree of freedom for t distribution
    return len(y)-2
def t_statistic(slope, standard_error):
    return slope/standard_error
def t_p_value(t0,df): # return two tailed p-value P(t>t0) + P(t<t0):
    if (t0<0): t0 = -t0
    return 2*t.sf(t0, df)

# %%
with open('chrom_dict.pickle', 'rb') as handle:
    chrom_dict = pickle.load(handle)

# %%
import os
statinfo = os.stat('chrom_dict.pickle')
statinfo
# Out:
# os.stat_result(st_mode=33188, st_ino=35966003, st_dev=54, st_nlink=1, st_uid=29233, st_gid=6320, st_size=27487850004, st_atime=1506472664, st_mtime=1504769490, st_ctime=1504769490)

# %%
chrom_dict
# Out:
# {1: array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         ...,
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [  2.,   1.,   2., ...,   2.,   2.,   2.],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan]]),
#  2: array([[  2.,   2.,   2., ...,   2.,   2.,   2.],
#         [  2.,   2.,   2., ...,   2.,   2.,   2.],
#         [  2.,   1.,   2., ...,   2.,   2.,   2.],
#         ...,
#         [  0.,   1.,   2., ...,   2.,   2.,   0.],
#         [  2.,   2.,   2., ...,   2.,   2.,   2.],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan]]),
#  3: array([[  2.,   2.,   2., ...,   2.,   1.,   2.],
#         [  1.,   1.,   2., ...,   0.,   1.,   0.],
#         [  2.,   2.,   2., ...,   2.,   2.,   2.],
#         ...,
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
# ...

# %%
valid_column = ['PID']
X_combined_pid = x_first_visit[valid_column]
labels_dict = {}
pid = X_combined_pid[['PID']].values.flatten()
for t in pid:
    labels_dict.setdefault(t,0)
for t in model.get_indices(159)[0]:
    labels_dict[pid[t]] = 1
fid = fam[['fid']]
counter = 0
fid_array = fid.values.flatten()
for t in labels_dict.keys():
    if t not in fid_array:
        print(str(t) +' '+ str(labels_dict[t]))
        counter += 1
print(counter)
patient_column_dict = {}
for i, t in enumerate(fid_array):
    if t in labels_dict.keys():
        patient_column_dict.setdefault(t,i) # pid corresponding to pos in fid
print(len(list(patient_column_dict.values())))
patient_column_dict
# Out:
# 01010013 0
# 01010033 0
# 01010071 0
# 01010127 0
# 01010170 0
# 01010174 0
# 01010184 0
# 01010250 0
# 01010254 0
# 01010326 0
# 01010362 0
# 01010475 0
# 01010497 0
# 01010725 0
# 01010793 0
# 01010837 0
# 01010862 0
# 01010863 0
# 01010866 0
# 01010869 0
# 01010870 0
# 01010877 0
# 01010888 0
# 01010900 0
# 01010901 0
# 01010904 0
# 01010905 1
# 01010909 0
# 01010910 1
# 01010914 0
# 01010915 0
# 01010916 0
# 01010918 0
# 01010929 0
# 01010943 0
# 01010946 0
# 01010956 0
# 01010972 0
# 01010979 0
# 01010981 0
# 01010994 0
# 01010998 0
# 01010999 0
# 01011001 0
# 01011011 0
# 01011012 0
# 01011021 0
# 01011054 1
# 01011070 0
# 01011072 1
# 01011074 0
# 01011091 0
# 01011100 0
# 01011164 0
# 01011182 0
# 02010003 1
# 02010015 0
# 02010229 0
# 02010238 0
# 02010286 0
# 02010473 0
# 02010507 0
# 02010581 0
# 02010658 0
# 02010677 1
# 02020021 0
# 02020032 0
# 02020040 0
# 02020053 0
# 02020057 0
# 02020064 0
# 02020067 0
# 02020069 0
# 02020078 0
# 02020080 0
# 02020083 0
# ...

# %%
labels_array = []
for t in patient_column_dict.keys():
    labels_array.append(labels_dict[t])
print(len(labels_array))
labels_array = np.array(labels_array)
# Out:
# 3463

# %%
c = 25
p_dict25 = {}
regr = linear_model.LinearRegression()
curr_snp_names = bim[['snp']].values.flatten()[bim[['chrom']].values.flatten() == str(c)]
for s in np.arange(chrom_dict[c].shape[0]):
#for s in np.arange(10):
    curr_snp = chrom_dict[c][:,list(patient_column_dict.values())][s,:] # the s-th snp in the c-th chromosome
    if (sum(~np.isnan(curr_snp)) > 1000):
        #print(len(curr_snp))
        #print(sum(~np.isnan(curr_snp)))
        curr_label = np.array(labels_array)[np.where(~np.isnan(curr_snp))[0]] 
        #print(len(curr_label))
        print(len(curr_snp[np.where(~np.isnan(curr_snp))[0]] ))
        x = curr_snp[np.where(~np.isnan(curr_snp))[0]] 
        y = curr_label
        model = regr.fit(np.array([[x] for x in x]), y)
        slope = model.coef_[0]
        intercept = model.intercept_
        y_pred = slope * x + intercept
        std_error = np.sqrt(sum( (y_pred-y)*(y_pred-y )  ) / len(y_pred))
        deg_of_freedom = len(y)-2
        t0 = slope / std_error
        tp = t_p_value(t0,deg_of_freedom)
        p_dict25.setdefault(curr_snp_names[s],tp)
# Out:
# 3461
# 3460
# 3451
# 3444
# 3457
# 3427
# 3459
# 3463
# 3446
# 3462
# 3435
# 3449
# 3459
# 3463
# 3458
# 3463
# 3462
# 3452
# 3460
# 3455
# 3463
# 3461
# 3443
# 3433
# 3459
# 3448
# 3457
# 3462
# 3460
# 3462
# 3437
# 3462
# 3463
# 3450
# 3454
# 3463
# 3449
# 3436
# 3463
# 3462
# 3459
# 3462
# 3456
# 3462
# 3463
# 3459
# 3435
# 3432
# 3458
# 3461
# 3461
# 3463
# 3462
# 3460
# 3458
# 3462
# 3463
# 3459
# 3455
# 3462
# 3457
# 3461
# 3458
# 3435
# 3459
# 3463
# 3461
# 3461
# 3462
# 3455
# 3461
# 3460
# 3461
# 3379
# 3463
# 3462
# 3460
# 3462
# 3457
# 3461
# 3461
# 3462
# 3452
# 3463
# 3460
# 3460
# 3462
# 3462
# 3461
# 3462
# 3265
# 3460
# 3459
# 3463
# 3460
# 3461
# 3462
# 3459
# 3462
# 3461
# 3462
# 3461
# 3460
# 3461
# 3462
# 3460
# 3461
# 3459
# 3459
# 3460
# 3338
# 3462
# 3461
# 3462
# 3460
# 3461
# 3460
# 3455
# 3459
# 3446
# 3459
# 3459
# 3462
# 3462
# 3439
# 3461
# 3458
# 3463
# 3460
# 3412
# 3461
# 3463
# 3459
# 3461
# 3463
# 3462
# 3462
# 3463
# 3459
# 3462
# 3463
# 3436
# ...

# %%
with open('p_dict25.pickle', 'rb') as handle:
    p_dict25 = pickle.load(handle)
plt.plot(-np.log10(np.array(list(p_dict25.values()))), 'ro',ms=2)
plt.title('p-value of ' +str(len(list(p_dict25.values())))+' snps on chromosome '+str(25) )
plt.show()
